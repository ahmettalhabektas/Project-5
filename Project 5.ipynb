# %% [markdown]
# https://www.kaggle.com/competitions/data-science-london-scikit-learn/overview

# %% [markdown]
# # Importing Libs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading data

# %%
train=pd.read_csv("train.csv",header=None)
test=pd.read_csv("test.csv",header=None)
train_labels=pd.read_csv("trainLabels.csv",header=None)

# %%
train.columns=list(range(1,41))
test.columns=list(range(1,41))

# %% [markdown]
# # EDA

# %%
train.head()
# Out:
#          1         2         3         4         5         6         7   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          8         9         10  ...        31        32        33        34  \
# 0  1.594506 -0.051608  0.663234  ... -0.850465 -0.622990 -1.833057  0.293024
# 1  2.619246 -0.765884 -0.093780  ... -0.819750  0.012037  2.038836  0.468579
# 2 -4.219054 -1.184919 -1.240310  ... -0.604501  0.750054 -3.360521  0.856988
# 3  4.499666  1.038741 -1.092716  ...  1.022959  1.275598 -3.480110 -1.065252
# 4 -4.290282 -1.761308  0.807652  ...  0.513906 -1.803473  0.518579 -0.205029
#
#          35        36        37        38        39        40
# ...

# %%
train.shape,train_labels.shape,test.shape
# Out:
# ((1000, 40), (1000, 1), (9000, 40))

# %%
train[41]=train_labels

# %%
train.head()
# Out:
#          1         2         3         4         5         6         7   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          8         9         10  ...        32        33        34        35  \
# 0  1.594506 -0.051608  0.663234  ... -0.622990 -1.833057  0.293024  3.552681
# 1  2.619246 -0.765884 -0.093780  ...  0.012037  2.038836  0.468579 -0.517657
# 2 -4.219054 -1.184919 -1.240310  ...  0.750054 -3.360521  0.856988 -2.751451
# 3  4.499666  1.038741 -1.092716  ...  1.275598 -3.480110 -1.065252  2.153133
# 4 -4.290282 -1.761308  0.807652  ... -1.803473  0.518579 -0.205029 -4.744566
#
#          36        37        38        39        40  41
# ...

# %%
abs(train.corr()[41]).sort_values(ascending=False)
# Out:
# 41    1.000000
# 15    0.476171
# 13    0.460738
# 19    0.289508
# 40    0.264656
# 7     0.252976
# 35    0.236116
# 37    0.231733
# 33    0.227027
# 29    0.207949
# 24    0.172938
# 5     0.150652
# 12    0.075276
# 21    0.075135
# 27    0.064633
# 16    0.060556
# 34    0.053928
# 2     0.052153
# 23    0.046953
# 20    0.046036
# 8     0.040523
# 38    0.039376
# 9     0.037534
# 26    0.036663
# 1     0.028058
# 10    0.026841
# 28    0.019778
# 39    0.019690
# 22    0.018645
# 14    0.018214
# 18    0.018021
# 25    0.017121
# 31    0.015797
# 6     0.015151
# 36    0.012533
# 32    0.012458
# 17    0.012234
# 30    0.012022
# 11    0.010233
# 4     0.007439
# 3     0.005618
# Name: 41, dtype: float64

# %%
train[15]
# Out:
# 0      4.305643
# 1     -0.679051
# 2     -4.862125
# 3      1.622659
# 4     -5.031497
#          ...
# 995   -0.710082
# 996    2.593422
# 997    3.724396
# 998   -4.599050
# 999   -0.985344
# Name: 15, Length: 1000, dtype: float64

# %% [markdown]
# # Feature engineering

# %%
train[15]=train[15]*2
train[13]=train[13]*2
train[19]=train[19]*2
train[40]=train[40]*2
train[7]=train[7]*2

# %% [markdown]
# # Spliting data

# %%
X=train.drop(41,axis=1)
y=train.iloc[:,-1]
Z=test

# %%
from sklearn.naive_bayes import GaussianNB , BernoulliNB # 2 şey için
from sklearn.naive_bayes import MultinomialNB# 3 ve daha fazla için
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
g=GaussianNB()
b=BernoulliNB()
k=KNeighborsClassifier(n_neighbors=10)
d=DecisionTreeClassifier()
gbc=GradientBoostingClassifier()
log=LogisticRegression()
svc=SVC()

# %%
#önce yukarda olduğu gibi tanımlamak lazım
algorithms = [g,b,k,log,d,gbc]
names = ['GaussianNB', 'BernoulliNB', 'K Nearest', 'Logistic', 'Single Tree', 'Gradient Boost']

# %%
for i in range(len(algorithms)):
    algorithms[i] = algorithms[i].fit(X, y)
# print metrics 
for i in range(len(algorithms)):
    pred=algorithms[i].predict(Z)
    submission = pd.DataFrame(pred)
    submission.columns = ['Solution']
    submission['Id'] = np.arange(1,submission.shape[0]+1)
    submission = submission[['Id', 'Solution']]
    submission.to_csv('submission_{}.csv'.format(algorithms[i]), index=False)
